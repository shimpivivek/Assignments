# %% [markdown]
# ## Q1. What is the Probability density function?

# %% [markdown]
# The pdf is generated by smoothing of histogram using kernal density estimator.

# %% [markdown]
# ## Q2. What are the types of Probability distribution?

# %% [markdown]
# There are several types of probability distributions, each describing the behavior of random variables in specific ways. some are given below
# 1) Normal/Gaussain Distribution
# 2) Bernoulli's
# 2) Unifrom
# 4) Log normal
# 5) Poission
# 6) Power law
# 7) Binomial

# %% [markdown]
# ## Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %%
from scipy.stats import norm
import numpy as np
probability_pdf = norm.pdf(x, loc=mean, scale=std)
print(probability_pdf)

# %% [markdown]
# ## Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# The Binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent Bernoulli trials, where each trial has two possible outcomes (success or failure) and the probability of success remains constant for each trial.
#
# The properties of the binomial distribution are:
#
# 1) There are two possible outcomes: true or false, success or failure, yes or no.
# 2) There is ‘n’ number of independent trials or a fixed number of n times repeated trials.
# 3) The probability of success or failure remains the same for each trial.
# 4) Only the number of success is calculated out of n independent trials.
# 5) Every trial is an independent trial, which means the outcome of one trial does not affect the outcome of another trial.
#
# Example of Binomial distribution:_
#
# 1) Fliping of coin N times.
# 2) Winning a lottery in N times.

# %% [markdown]
# ## Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

n =10
p = 0.4

generated_Random_sample=np.random.binomial(n,p,size=1000)
plt.hist(generated_Random_sample)
plt.xlabel("Success")
plt.ylabel("Probablity Density")
plt.title("Histogram for Binomail distribution")
plt.show()

# %% [markdown]
# ## Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

# %%
from scipy.stats import poisson

poisson.cdf(k,mu)


#k: The point at which you want to calculate the CDF.
#mu: The mean parameter of the Poisson distribution
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 from scipy.stats import poisson
# ----> 3 poisson.cdf(k,mu)
#       6 #k: The point at which you want to calculate the CDF.
#       7 #mu: The mean parameter of the Poisson distribution
#
# NameError: name 'k' is not defined

# %% [markdown]
# ## Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# %%
random_sample= poisson.rvs(mu=5,size=1000)
print(np.mean(random_sample))
print(np.var(random_sample))
# Out:
# 4.957
# 5.3611509999999996

# %% [markdown]
# ## Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# In Binomail Distribution, mean is given by
#
# mean=np , here (  n= no trails and p = probablity of sucess )
# variance = np (1-p)
#
# In Poisson Distribution
#
# mean = variance = Lamba (lambda = the average rate of occurrences in a fixed interval)

# %% [markdown]
# ## Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# The least frequent data points appear in the tails of the distribution, which are the extreme values that are far from the mean. As you move away from the mean, the frequency of data points decreases.
